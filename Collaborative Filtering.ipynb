# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from IPython.display import display, Image
warnings.filterwarnings("ignore")

from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy

# %%
books = pd.read_csv("data/old/Books.csv")
users = pd.read_csv("data/old/Users.csv")
ratings = pd.read_csv('data/old/Ratings.csv')

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (271360, 8)
# (1048575, 3)
# (278858, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
ratings_with_book_titles = ratings.merge(books,on='ISBN')

# %%
ratings_with_book_titles.head()
# Out:
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose  \
# 1     2313  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 2     6543  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 3     8680  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 4    10314  034545104X            9  Flesh Tones: A Novel  M. J. Rose
#
#   Year-Of-Publication         Publisher
# 0                2002  Ballantine Books  \
# 1                2002  Ballantine Books
# 2                2002  Ballantine Books
# 3                2002  Ballantine Books
# 4                2002  Ballantine Books
#
#                                          Image-URL-S
# 0  http://images.amazon.com/images/P/034545104X.0...  \
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# 4  http://images.amazon.com/images/P/034545104X.0...
#
#                                          Image-URL-M
# 0  http://images.amazon.com/images/P/034545104X.0...  \
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# 4  http://images.amazon.com/images/P/034545104X.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# 4  http://images.amazon.com/images/P/034545104X.0...

# %%
ratings_with_book_titles.drop(columns=["ISBN","Image-URL-S","Image-URL-M"],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 # ratings_with_book_titles.drop(columns=["ISBN","Image-URL-S","Image-URL-M"],axis=1,inplace=True)
# ----> 2 ratings_with_book_titles.drop(columns=["Location"],axis=1,inplace=True)
#
# File c:\Program Files\Python310\lib\site-packages\pandas\core\frame.py:5266, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5118 def drop(
#    5119     self,
#    5120     labels: IndexLabel = None,
#    (...)
#    5127     errors: IgnoreRaise = "raise",
#    5128 ) -> DataFrame | None:
#    5129     """
#    5130     Drop specified labels from rows or columns.
#    5131
#    (...)
#    5264             weight  1.0     0.8
#    5265     """
# -> 5266     return super().drop(
#    5267         labels=labels,
#    5268         axis=axis,
#    5269         index=index,
#    5270         columns=columns,
#    5271         level=level,
#    5272         inplace=inplace,
#    5273         errors=errors,
#    5274     )
#
# File c:\Program Files\Python310\lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File c:\Program Files\Python310\lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File c:\Program Files\Python310\lib\site-packages\pandas\core\indexes\base.py:6696, in Index.drop(self, labels, errors)
#    6694 if mask.any():
#    6695     if errors != "ignore":
# -> 6696         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6697     indexer = indexer[~mask]
#    6698 return self.delete(indexer)
#
# KeyError: "['Location'] not found in axis"

# %%
ratings_with_book_titles
# Out:
#         User-ID  Book-Rating
# 0        276725            0  \
# 1          2313            5
# 2          6543            0
# 3          8680            5
# 4         10314            9
# ...         ...          ...
# 941108   250764            0
# 941109   250764            0
# 941110   250764            0
# 941111   250764            0
# 941112   250764            0
#
#                                                Book-Title        Book-Author
# 0                                    Flesh Tones: A Novel         M. J. Rose  \
# 1                                    Flesh Tones: A Novel         M. J. Rose
# 2                                    Flesh Tones: A Novel         M. J. Rose
# 3                                    Flesh Tones: A Novel         M. J. Rose
# 4                                    Flesh Tones: A Novel         M. J. Rose
# ...                                                   ...                ...
# 941108                                       HIDDEN FIRES  JANETTE RADCLIFFE
# 941109                     Cheyenne (Fortunes West, No 2)         A.R. Riefe
# 941110  Glamorous Movie Stars of the Thirties: Paper D...        Tom Tierney
# 941111  Schiaparelli Fashion Review: Paper Dolls in Fu...        Tom Tierney
# 941112           Lady Laughing Eyes (To Have and to Hold)          Lee Damon
#
#        Year-Of-Publication              Publisher
# 0                     2002       Ballantine Books  \
# 1                     2002       Ballantine Books
# 2                     2002       Ballantine Books
# 3                     2002       Ballantine Books
# 4                     2002       Ballantine Books
# ...                    ...                    ...
# 941108                1978                   Dell
# 941109                1988  New Amer Library (Mm)
# 941110                1982     Dover Publications
# 941111                1988     Dover Publications
# 941112                1984             Jove Books
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/034545104X.0...
# 1       http://images.amazon.com/images/P/034545104X.0...
# 2       http://images.amazon.com/images/P/034545104X.0...
# 3       http://images.amazon.com/images/P/034545104X.0...
# 4       http://images.amazon.com/images/P/034545104X.0...
# ...                                                   ...
# 941108  http://images.amazon.com/images/P/0440106575.0...
# 941109  http://images.amazon.com/images/P/0451157516.0...
# 941110  http://images.amazon.com/images/P/048623715X.0...
# 941111  http://images.amazon.com/images/P/0486256588.0...
# 941112  http://images.amazon.com/images/P/0515069434.0...
#
# [941113 rows x 7 columns]

# %% [markdown]
# ### Collaborative Filtering

# %%
# users with more than 180 book ratings
rate_threshold = 180

# Count ratings per user
num_ratings_per_user = ratings_with_book_titles.groupby('User-ID')['Book-Rating'].count()

# Filter users with more than the minimum threshold
user_ids = num_ratings_per_user[num_ratings_per_user >rate_threshold].index

# %%
# Filter ratings from user_ids
user_ratings =ratings_with_book_titles[ratings_with_book_titles['User-ID'].isin(user_ids)]

# %%
min_rate_count_thresh=50
rating_counts= user_ratings.groupby('Book-Title').count()['Book-Rating']
popular_books = rating_counts[rating_counts >=min_rate_count_thresh].index

# %%
final_ratings = user_ratings[user_ratings['Book-Title'].isin(popular_books)]

# %%
pivot_table = final_ratings.pivot_table(index='Book-Title',columns='User-ID'
                          ,values='Book-Rating')
pivot_table
# Out:
# User-ID                                             254     2033    2276
# Book-Title
# 1984                                                   9.0     NaN     NaN  \
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN    10.0
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     0.0     NaN
#
# User-ID                                             2766    2977    3363
# Book-Title
# 1984                                                   NaN     NaN     NaN  \
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     7.0     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     7.0     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     0.0
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             4017    4385    6251
# Book-Title
# 1984                                                   NaN     NaN     NaN  \
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     0.0
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     0.0
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             6323    ...  249862
# Book-Title                                                  ...
# 1984                                                   NaN  ...     NaN  \
# 1st to Die: A Novel                                    NaN  ...     NaN
# 2nd Chance                                             NaN  ...     NaN
# 4 Blondes                                              NaN  ...     NaN
# A Bend in the Road                                     NaN  ...     NaN
# ...                                                    ...  ...     ...
# Year of Wonders                                        NaN  ...     NaN
# You Belong To Me                                       0.0  ...     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN  ...     NaN
# Zoya                                                   NaN  ...     NaN
# \O\" Is for Outlaw"                                    NaN  ...     NaN
#
# User-ID                                             249894  250184  250405
# Book-Title
# 1984                                                   NaN     NaN     NaN  \
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     0.0     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             250764  277427  277478
# Book-Title
# 1984                                                   NaN     NaN     NaN  \
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   0.0     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             277639  278188  278418
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             0.0     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     0.0     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# [656 rows x 831 columns]

# %%
pivot_table.fillna(0,inplace=True)
pivot_table
# Out:
# User-ID                                             254     2033    2276
# Book-Title
# 1984                                                   9.0     0.0     0.0  \
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0    10.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             2766    2977    3363
# Book-Title
# 1984                                                   0.0     0.0     0.0  \
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     7.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     7.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             4017    4385    6251
# Book-Title
# 1984                                                   0.0     0.0     0.0  \
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             6323    ...  249862
# Book-Title                                                  ...
# 1984                                                   0.0  ...     0.0  \
# 1st to Die: A Novel                                    0.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# 4 Blondes                                              0.0  ...     0.0
# A Bend in the Road                                     0.0  ...     0.0
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# User-ID                                             249894  250184  250405
# Book-Title
# 1984                                                   0.0     0.0     0.0  \
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             250764  277427  277478
# Book-Title
# 1984                                                   0.0     0.0     0.0  \
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             277639  278188  278418
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [656 rows x 831 columns]

# %% [markdown]
# ### cosine_similarity
# matrix as input, each rows represent a data point and  columns represent a feature.
# So in my data, rows represent users,  columns represent book titles.
# Function calculates the cosine similarity between every pair of users in the matrix, measuring angle between two vectors;
# a 1 score shows perfect similarity,
# and 0 shows perfect dissimilarity.
# Output is square matrix where each element (i, j) represents the cosine similarity score between user i and user j.
#
# Use this matrix to recommend items to users based on their similarity to other users who have rated those books highly.
# For example, find the user with the highest cosine similarity to a particular user and recommend the items that the similar user rated highly.

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_score = cosine_similarity(pivot_table)

# %%
from sklearn.metrics.pairwise import cosine_similarity 

similarity_score = cosine_similarity(pivot_table)

def recommend(book_name):
    index = np.where(pivot_table.index==book_name)[0][0]
    similar_books = sorted(list(enumerate(similarity_score[index])),key=lambda x:x[1], reverse=True)[1:6]
    
    data = []
    
    for i in similar_books:
        item = []
        temp_df = books[books['Book-Title'] == pivot_table.index[i[0]]]
        item.append(temp_df['Book-Title'].values[0]) 
        item.append(temp_df['Book-Author'].values[0])
        
        similarity = i[1]  # similarity score
        item.append(similarity)  # Adding similarity score
        
        data.append(item)
    return data

# %%
recommended_books = recommend("The Alienist")
for book in recommended_books:
    print(f"Book Title: {book[0]}")
    print(f"Author: {book[1]}")
    print(f"Similarity Score: {book[2]}")
    print()
# Out:
# Book Title: The Poisonwood Bible
# Author: Barbara Kingsolver
# Similarity Score: 0.30163647403280186
#
# Book Title: The Angel of Darkness
# Author: Caleb Carr
# Similarity Score: 0.2955209461735067
#
# Book Title: The Cradle Will Fall
# Author: Mary Higgins Clark
# Similarity Score: 0.28569389653568555
#
# Book Title: The Shipping News : A Novel
# Author: Annie Proulx
# Similarity Score: 0.27750180972638644
#
# Book Title: Secret History
# Author: DONNA TARTT
# Similarity Score: 0.25964676550264176

# %%
# Out:
# RMSE: 3.5036
# 3.5036455509735864
